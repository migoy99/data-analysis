# %%
#TRINIDAD, MIGUEL FRANCO T.
#BUSINESS/DATA ANALYTICS WITH PYTHON
#Final Exam Exploratory Data Analysis and Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#loading and reading the dataset to the dataframe called 'dframe'
dframe = pd.read_csv("C://Users/Administrator/Desktop/ELBIZAN FINAL/RealEstate.csv")

# %%
dframe.head()
# Out:
#    house age  distance to the nearest MRT station  \
# 0       32.0                             84.87882
# 1       19.5                            306.59470
# 2       13.3                            561.98450
# 3       13.3                            561.98450
# 4        5.0                            390.56840
#
#    number of convenience stores  latitude  longitude  house price of unit area
# 0                            10  24.98298  121.54024                      37.9
# 1                             9  24.98034  121.53951                      42.2
# 2                             5  24.98746  121.54391                      47.3
# 3                             5  24.98746  121.54391                      54.8
# 4                             5  24.97937  121.54245                      43.1

# %%
#gives us a summary information of the dframe datas set
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   house age                            414 non-null    float64
#  1   distance to the nearest MRT station  414 non-null    float64
#  2   number of convenience stores         414 non-null    int64
#  3   latitude                             414 non-null    float64
#  4   longitude                            414 non-null    float64
#  5   house price of unit area             414 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 19.5 KB

# %%
#Gives us a statistical summary such as the mean, minimum, maximum, etc.
dframe.describe()
# Out:
#         house age  distance to the nearest MRT station  \
# count  414.000000                           414.000000
# mean    17.712560                          1083.885689
# std     11.392485                          1262.109595
# min      0.000000                            23.382840
# 25%      9.025000                           289.324800
# 50%     16.100000                           492.231300
# 75%     28.150000                          1454.279000
# max     43.800000                          6488.021000
#
#        number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# min                        0.000000   24.932070  121.473530
# 25%                        1.000000   24.963000  121.528085
# 50%                        4.000000   24.971100  121.538630
# ...

# %%
#Gives us the pairwise correlation of all the columns in the data frame.
dframe.corr()
# Out:
#                                      house age  \
# house age                             1.000000
# distance to the nearest MRT station   0.025622
# number of convenience stores          0.049593
# latitude                              0.054420
# longitude                            -0.048520
# house price of unit area             -0.210567
#
#                                      distance to the nearest MRT station  \
# house age                                                       0.025622
# distance to the nearest MRT station                             1.000000
# number of convenience stores                                   -0.602519
# latitude                                                       -0.591067
# longitude                                                      -0.806317
# house price of unit area                                       -0.673613
#
#                                      number of convenience stores  latitude  \
# ...

# %%
sns.pairplot(dframe)
